# %% [markdown]
# <a href="https://colab.research.google.com/github/Jojohere05/PRODIGY_DS_02/blob/main/prodigy_task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
add='https://github.com/m4gaikwad/PandasTutorial/raw/main/online_store_customer_data.csv'

# %%
df=pd.read_csv(add,on_bad_lines='skip')
df.head(10)
# Out:
#   Transaction_date  Transaction_ID  Gender   Age Marital_status  State_names  \
# 0         1/1/2019          151200  Female  19.0         Single       Kansas
# 1         1/1/2019          151201    Male  49.0         Single     Illinois
# 2         1/1/2019          151202    Male  63.0        Married   New Mexico
# 3         1/1/2019          151203     NaN  18.0         Single     Virginia
# 4         1/1/2019          151204    Male  27.0         Single  Connecticut
# 5         1/3/2019          151205    Male  71.0         Single       Hawaii
# 6         1/3/2019          151206  Female  34.0        Married   New Mexico
# 7         1/3/2019          151207    Male  37.0        Married  Connecticut
# 8         1/4/2019          151208    Male  75.0        Married      Florida
# 9         1/4/2019          151209  Female  41.0        Married      Vermont
#
#     Segment Employees_status Payment_method  Referal  Amount_spent
# ...

# %% [markdown]
# ## **Cleaning of** **data**

# %%
df.shape
# Out:
# (2512, 11)

# %%
df.Age.isna().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Transaction_date      0
# Transaction_ID        0
# Gender               28
# Age                   0
# Marital_status        0
# State_names           0
# Segment               0
# Employees_status     26
# Payment_method        0
# Referal             155
# Amount_spent        242
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 451

# %%
cleaned_dataset=df.dropna(subset=['Gender','Referal','Amount_spent'])
print(cleaned_dataset)
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 0            1/1/2019          151200  Female  19.0         Single
# 1            1/1/2019          151201    Male  49.0         Single
# 2            1/1/2019          151202    Male  63.0        Married
# 5            1/3/2019          151205    Male  71.0         Single
# 6            1/3/2019          151206  Female  34.0        Married
# ...               ...             ...     ...   ...            ...
# 2506        4/30/2021          153694    Male  34.0         Single
# 2507         5/1/2021          153695  Female  57.0         Single
# 2508         5/1/2021          153696  Female  36.0        Married
# 2509         5/1/2021          153697    Male  22.0         Single
# 2511         5/1/2021          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 0             Kansas     Basic     Unemployment          Other      1.0
# ...

# %% [markdown]
# # **Data Analysis**

# %%
df[(df['Age']<=40)&(df['Gender']=='Female')&(df['Marital_status']=='Single')]
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 0            1/1/2019          151200  Female  19.0         Single
# 24          1/10/2019          151224  Female  32.0         Single
# 31          1/13/2019          151231  Female  21.0         Single
# 42          1/17/2019          151242  Female  16.0         Single
# 58          1/25/2019          151258  Female  32.0         Single
# ...               ...             ...     ...   ...            ...
# 2404        3/27/2021          153592  Female  39.0         Single
# 2420         4/2/2021          153608  Female  37.0         Single
# 2423         4/3/2021          153611  Female  27.0         Single
# 2459        4/14/2021          153647  Female  24.0         Single
# 2472        4/19/2021          153660  Female  16.0         Single
#
#          State_names Segment Employees_status Payment_method  Referal  \
# 0             Kansas   Basic     Unemployment          Other      1.0
# ...

# %%
import numpy as np

# %%
df['Age_category']=np.where(df['Age']<30,'Young',np.where(df['Age']<=50,'middle_aged','old'))

# %%
df['Age_category']
# Out:
# 0             Young
# 1       middle_aged
# 2               old
# 3             Young
# 4             Young
#            ...
# 2507            old
# 2508    middle_aged
# 2509          Young
# 2510    middle_aged
# 2511    middle_aged
# Name: Age_category, Length: 2512, dtype: object

# %%
df.groupby(['Age_category'])['Age'].count()
# Out:
# Age_category
# Young           537
# middle_aged     902
# old            1073
# Name: Age, dtype: int64

# %%
df[['Age_category','Amount_spent']].groupby(df['Age_category']).mean()
# Out:
# <ipython-input-63-f7b2fdc7bed1>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[['Age_category','Amount_spent']].groupby(df['Age_category']).mean()
#               Amount_spent
# Age_category
# Young          1478.187584
# middle_aged    1391.679877
# old            1411.606673

# %%
pd.crosstab(df['Age_category'],df['Marital_status'])
# Out:
# Marital_status  Married  Single
# Age_category
# Young               321     216
# middle_aged         527     375
# old                 625     448
